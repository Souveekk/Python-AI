# %% [markdown]
# <a href="https://colab.research.google.com/github/Souveekk/Python-AI/blob/main/NLP_Tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
corpus = """
My name is Demetrius Johnson. I am a professional MMA fighter. I am 15 time world champion!, I have now retired and run a coaching school.
"""

# %%
print(corpus)
# Out:
# My name is Demetrius Johnson. I am a professional MMA fighter. I am 15 time world champion!, I have now retired and run a coaching school.

# %%
### Paragraph --> sentences
import nltk
from nltk.tokenize import sent_tokenize
nltk.download('punkt_tab')
documents=sent_tokenize(corpus)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
print(type(documents))
documents
# Out:
# <class 'list'>
# ['\nMy name is Demetrius Johnson.',
#  'I am a professional MMA fighter.',
#  'I am 15 time world champion!, I have now retired and run a coaching school.']

# %%
### Paragraphs --> words
### Sentences --> words

from nltk.tokenize import word_tokenize
words=word_tokenize(corpus)
print(type(words))
print(words)
# Out:
# <class 'list'>
# ['My', 'name', 'is', 'Demetrius', 'Johnson', '.', 'I', 'am', 'a', 'professional', 'MMA', 'fighter', '.', 'I', 'am', '15', 'time', 'world', 'champion', '!', ',', 'I', 'have', 'now', 'retired', 'and', 'run', 'a', 'coaching', 'school', '.']
